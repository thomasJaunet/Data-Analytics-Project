# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
filename = '../files/listings_borough.csv'
data_borough = pd.read_csv(filename)
del data_borough['Unnamed: 0']
data_borough.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50204 entries, 0 to 50203
# Data columns (total 14 columns):
# id                                   50204 non-null int64
# price                                50204 non-null int64
# minimum_nights                       50204 non-null int64
# number_of_reviews                    50204 non-null int64
# reviews_per_month                    50204 non-null float64
# availability_365                     50204 non-null int64
# neighbourhood_group_Bronx            50204 non-null int64
# neighbourhood_group_Brooklyn         50204 non-null int64
# neighbourhood_group_Manhattan        50204 non-null int64
# neighbourhood_group_Queens           50204 non-null int64
# neighbourhood_group_Staten Island    50204 non-null int64
# room_type_Entire home/apt            50204 non-null int64
# room_type_Private room               50204 non-null int64
# room_type_Shared room                50204 non-null int64
# dtypes: float64(1), int64(13)
# ...

# %%
y = data_borough['price']
reviews_nb = data_borough['number_of_reviews']

plt.scatter(reviews_nb, y)
plt.show()

# %%
sum(y>500)
# Out:
# 1046

# %%
data_borough_500 = data_borough[data_borough['price'] < 500]
y_500 = data_borough_500['price']
reviews_nb_500 = data_borough_500['number_of_reviews']

# %%
plt.scatter(reviews_nb_500, y_500)
plt.show()

# %% [markdown]
# After this analysis, we can see that the number of reviews doesn't explain the price. We can drop this feature, it is useless for our model

# %%
avail = data_borough['availability_365']

plt.scatter(avail,y)
plt.show()

# %%
avail_500 = data_borough_500['availability_365']

plt.scatter(avail_500,y_500)
plt.show()

# %% [markdown]
# We conclude that availability is not an explanatory feature for the price

# %%
r_m = data_borough['reviews_per_month']

plt.scatter(r_m,y)
plt.show()

# %%
r_m_500 = data_borough_500['reviews_per_month']

plt.scatter(r_m_500,y_500)
plt.show()

# %% [markdown]
# Not explanatory either

# %%
r_m = data_borough['minimum_nights']

plt.scatter(r_m,y)
plt.show()

# %%
r_m_500 = data_borough_500['minimum_nights']

plt.scatter(r_m_500,y_500)
plt.show()

# %% [markdown]
# Not very explanatory

# %%
data_borough.corr()
# Out:
#                                          id     price  minimum_nights  \
# id                                 1.000000 -0.008699       -0.012288
# price                             -0.008699  1.000000        0.030169
# minimum_nights                    -0.012288  0.030169        1.000000
# number_of_reviews                 -0.328280 -0.032608       -0.091832
# reviews_per_month                  0.150426 -0.042791       -0.138044
# availability_365                   0.042013  0.075478        0.154769
# neighbourhood_group_Bronx          0.037177 -0.039974       -0.013063
# neighbourhood_group_Brooklyn      -0.042246 -0.106229       -0.037660
# neighbourhood_group_Manhattan     -0.023701  0.171203        0.065040
# neighbourhood_group_Queens         0.083858 -0.083801       -0.034517
# neighbourhood_group_Staten Island  0.013403 -0.014667       -0.014946
# room_type_Entire home/apt         -0.065884  0.267831        0.078374
# ...

# %%
plt.pcolor(data_borough.corr(),cmap='coolwarm') 
plt.show()

# %%
data_borough.corr()['price'].plot(figsize = (24,8))
